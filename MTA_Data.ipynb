# %%
from urllib import request
import os
import pandas as pd

# %%
request.urlretrieve('https://worksheets.codalab.org/rest/bundles/0x219a956574434c6b952d9a2070baf9d9/contents/blob/glove.6B.100d.txt', '/Users/arjun17/Downloads/glove.6B.100d.txt')
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/http/client.py:587, in HTTPResponse._read_chunked(self, amt)
#     586 if amt is not None and amt <= chunk_left:
# --> 587     value.append(self._safe_read(amt))
#     588     self.chunk_left = chunk_left - amt
#
# File ~/anaconda3/lib/python3.10/http/client.py:632, in HTTPResponse._safe_read(self, amt)
#     631 if len(data) < amt:
# --> 632     raise IncompleteRead(data, amt-len(data))
#     633 return data
#
# IncompleteRead: IncompleteRead(6241 bytes read, 1951 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# Cell In[3], line 1
# ...

# %%
monthsNonLeapYear = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
monthsLeapYear = {1:31, 2:29, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

# %%
initialList = ['141018', '141025', '141101', '141108', '141115', '141122', '141129', '141206', '141213', '141220', '141227']
for dates in initialList:
    remote_url = f"http://web.mta.info/developers/data/nyct/turnstile/turnstile_" + f"{dates}" + f".txt"
    local_file = f"/Users/arjun17/Desktop/BigData Datasets/" + f"{dates[4:6]}" + "_" + f"{dates[2:4]}" + "_" + f"{dates[0:2]}" + f".txt"
    request.urlretrieve(remote_url, local_file)
start = 3
exit = 0
for i in range(15, 24):
    if i % 4 == 0:
        for k in range(1, 13):
            while start <= monthsLeapYear[k]:
                remote_url = f"http://web.mta.info/developers/data/nyct/turnstile/turnstile_" + f"{i:02d}" + f"{k:02d}" + f"{start:02d}" + f".txt"
                local_file = f"/Users/arjun17/Desktop/BigData Datasets/" + f"{start:02d}" + "_" + f"{k:02d}" + "_" + f"{i:02d}" + f".txt"
                request.urlretrieve(remote_url, local_file)
                start += 7
            start %= monthsLeapYear[k]
    else:
        for k in range(1, 13):
            while start <= monthsNonLeapYear[k]:
                remote_url = f"http://web.mta.info/developers/data/nyct/turnstile/turnstile_" + f"{i:02d}" + f"{k:02d}" + f"{start:02d}" + f".txt"
                local_file = f"/Users/arjun17/Desktop/BigData Datasets/" + f"{start:02d}" + "_" + f"{k:02d}" + "_" + f"{i:02d}" + f".txt"
                request.urlretrieve(remote_url, local_file)
                if f"{i:02d}" + f"{k:02d}" + f"{start:02d}" == "230429":
                    exit = 1
                    break
                start += 7
            if exit == 1:
                break
            start %= monthsNonLeapYear[k]
        if exit == 1:
            break

# %%
dir_list = os.listdir("/Users/arjun17/Desktop/BigData Datasets/")

# %%
years = {2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[], 2020:[], 2021:[], 2022:[], 2023:[]}
for j in range(14, 24):
    for val in dir_list:
        if str(j) == val[6:8]:
            years[int("20" + val[6:8])].append(val)
            continue

# %%
for k in years:
    df_csv_append = pd.DataFrame()
    for j in years[k]:
        df = pd.read_csv("/Users/arjun17/Desktop/BigData Datasets/" + j)
        df_csv_append = df_csv_append.append(df, ignore_index=True)
    df_csv_append.to_csv("/Users/arjun17/Desktop/BigData Datasets/20"+j[6:8]+".csv")
# Out:
# /var/folders/pn/s8nwhnk95w17lr2rwrxq16s80000gn/T/ipykernel_33165/539639705.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csv_append = df_csv_append.append(df, ignore_index=True)
# /var/folders/pn/s8nwhnk95w17lr2rwrxq16s80000gn/T/ipykernel_33165/539639705.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csv_append = df_csv_append.append(df, ignore_index=True)
# /var/folders/pn/s8nwhnk95w17lr2rwrxq16s80000gn/T/ipykernel_33165/539639705.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_csv_append = df_csv_append.append(df, ignore_index=True)
# ...

# %%
import shutil

# %%
shutil.disk_usage('/Users/arjun17').free
# Out:
# 267662708736
